# %% [markdown]
# Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
shl_data = pd.read_csv('Sleep_health_and_lifestyle_dataset.csv')
shl_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %% [markdown]
# Datacleaning

# %%
#check for duplicates
duplicates = shl_data.duplicated().sum()
print(duplicates)
# Out:
# 0

# %%
# Check for missing values
missing_values = shl_data.isnull().sum()
print(missing_values)
#found 219 missing values on sleep disorder column
# Out:
# Person ID                    0
# Gender                       0
# Age                          0
# Occupation                   0
# Sleep Duration               0
# Quality of Sleep             0
# Physical Activity Level      0
# Stress Level                 0
# BMI Category                 0
# Blood Pressure               0
# Heart Rate                   0
# Daily Steps                  0
# Sleep Disorder             219
# dtype: int64

# %% [markdown]
# Noticed that the None value should be there after research. The meaning of None is that the person in question doesnt have sleep disorder

# %%
#made None to a category we can use
none_count = (shl_data['Sleep Disorder'] == 'None').sum()
print(f"Amount of 'None': {none_count}")
shl_data['Sleep Disorder'].fillna('None', inplace=True)
missing_values = shl_data['Sleep Disorder'].isnull().sum()
print(f"missing values after cleaning: {missing_values}")
# Out:
# Amount of 'None': 0
# missing values after cleaning: 0
# C:\Users\Nikla\AppData\Local\Temp\ipykernel_32268\1257017061.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   shl_data['Sleep Disorder'].fillna('None', inplace=True)

# %%
#Checking the object columns to see that there is no double where there might be a small/large letter difference
print(shl_data['Gender'].unique())
print(shl_data['Gender'].value_counts())
print(shl_data['Occupation'].unique())
print(shl_data['Occupation'].value_counts())
print(shl_data['BMI Category'].unique())
print(shl_data['BMI Category'].value_counts())
print(shl_data['Blood Pressure'].unique())
print(shl_data['Blood Pressure'].value_counts())
print(shl_data['Sleep Disorder'].unique())
print(shl_data['Sleep Disorder'].value_counts())
# Out:
# ['Male' 'Female']
# Gender
# Male      189
# Female    185
# Name: count, dtype: int64
# ['Software Engineer' 'Doctor' 'Sales Representative' 'Teacher' 'Nurse'
#  'Engineer' 'Accountant' 'Scientist' 'Lawyer' 'Salesperson' 'Manager']
# Occupation
# Nurse                   73
# Doctor                  71
# Engineer                63
# Lawyer                  47
# Teacher                 40
# Accountant              37
# Salesperson             32
# Scientist                4
# Software Engineer        4
# Sales Representative     2
# Manager                  1
# Name: count, dtype: int64
# ['Overweight' 'Normal' 'Obese' 'Normal Weight']
# BMI Category
# Normal           195
# Overweight       148
# Normal Weight     21
# Obese             10
# Name: count, dtype: int64
# ['126/83' '125/80' '140/90' '120/80' '132/87' '130/86' '117/76' '118/76'
#  '128/85' '131/86' '128/84' '115/75' '135/88' '129/84' '130/85' '115/78'
# ...

# %%
print(shl_data.describe())
print(shl_data.dtypes)
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
numerical_data=shl_data.select_dtypes(include=['int64', 'float64'])
plt.figure(figsize=(10,8))
sns.heatmap(numerical_data.corr(),annot=True,cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Rött (positiv korrelation): När en variabel ökar, tenderar den andra också att öka.
# Blått (negativ korrelation): När en variabel ökar, tenderar den andra att minska.
# Vitt (ingen korrelation): Det finns inget tydligt samband mellan variablerna.
